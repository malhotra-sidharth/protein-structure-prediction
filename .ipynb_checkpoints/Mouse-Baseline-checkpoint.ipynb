# %%
from utils.helper import Extract
import time
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score
import os
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import math

# %%
class TrainRNN:
    def __init__(self, hidden_size=20, decay_rate = 0):
        self.extractor = Extract()
        self.criterion = torch.nn.MSELoss(reduction='sum')
        self.traindfXY = None
        self.testdfXY = None
        self.xd = None
        self.yd = None
        self.helix_count = np.zeros(20)
        self.no_helix_count = np.zeros(20)
        self.total_count = np.zeros(20)

    def loadTestTrainData(self, one_hot_encoded_df_train_list, one_hot_encoded_df_test_list, logging=False):
        if logging:
            print('Train data extraction started.') 
        self.traindfXY = self.extractor.get_whole_seq_data(one_hot_encoded_df_train_list, logging)
        self.xd, self.yd = len(self.traindfXY), len(self.traindfXY)

        print(self.xd)

        if logging:
            print('Test data extraction started.') 
        self.testdfXY = self.extractor.get_whole_seq_data(one_hot_encoded_df_test_list, logging)

        if logging:
            print("Test and Train data extracted.")

    def trainNN(self, num_epochs=5, logging=False):
        # shuffle dataset
        num_prots = len(self.traindfXY)
        for i in range(num_prots):
            #Get a protein
            trainX, trainY = self.traindfXY[i]
            num_acids, _ = trainX.shape
            for j in range(num_acids):
                if trainY[j] > 0.9:
                    self.helix_count += trainX[j]
                else:
                    self.no_helix_count += trainX[j]
                self.total_count += trainX[j]

    def predict(self, inputdfXY):
        num_prots = len(inputdfXY)
        protein_list = []
        for i in range(num_prots):
            #Get a protein
            testX, testY = inputdfXY[i]
            num_acids, _ = testX.shape
            y_pred_tensor = np.zeros(num_acids)
            for j in range(num_acids):
                res_in_helix = np.dot(testX[j],self.helix_count)
                res_tot = np.dot(testX[j],self.total_count)
                # Run Model One Acid
                y_pred_tensor[j] = res_in_helix/res_tot 
            rmse = math.sqrt(((testY - y_pred_tensor)**2).mean(axis=None))
            avg_loss = rmse #/num_acids
            protein_list.append((avg_loss,y_pred_tensor,testY))
        return protein_list
  
  
    def predict_on_test_data(self, batch_size = 1, start = 0, single_protein = False):
        return self.predict(self.testdfXY)

    def predict_on_outside_data(self, outside_data_one_hot_df_list, batch_size = 1, start = 0, single_protein = False, logging = False):
        if logging:
            print("Seperating Labels")
        outsideXY = self.extractor.get_whole_seq_data(outside_data_one_hot_df_list, logging)
        if logging:
            print("Running Predictions")
        return self.predict(outsideXY)

# %%
extract = Extract()

# %%
train_df_list = extract.load_all_csv('./data/mouse/train')
test_df_list = extract.load_all_csv('./data/mouse/test')
# debug_df_list = extract.load_all_csv('./data/enc_debug_set')

# %%
fc_model_win_10 = TrainRNN()

# %%
fc_model_win_10.loadTestTrainData(train_df_list, test_df_list, logging=False)
# Out:
# 2538

# %%
fc_model_win_10.trainNN(num_epochs=20, logging=True)

# %%
predicted_prots_10 = fc_model_win_10.predict_on_test_data()

# %%
n = 5
plt.figure(figsize=(20, 6))
plt.plot(predicted_prots_10[n][1], color='blue')
plt.plot(predicted_prots_10[n][2], color='orange')
print(predicted_prots_10[n][0])
# Out:
# 0.001491140417158895

# %%
n = 5
plt.figure(figsize=(20, 6))
plt.plot(predicted_prots
plt.figure(figsize=(20, 6))
plt.plot(predicted_prots_10[n][1][0], color='blue')
plt.plot(predicted_prots_10[n][2][0], color='orange')

# %%
predicted_prots_10 = fc_model_win_10.predict_on_test_data()
n = 5
plt.figure(figsize=(20, 6))
plt.plot(predicted_prots_10[n][1], color='blue')
plt.plot(predicted_prots_10[n][2], color='orange')

# %%
# cwd = os.getcwd()
# path = cwd + "/" + "models/mouse/fcnn_win_10_epochs_150.pt"
# fc_model_win_10.trainNN(num_epochs=50, logging=True, save_path=path, save_after_epochs=50)
# predicted_prots_10 = fc_model_win_10.predict_on_test_data()
n = 10
plt.figure(figsize=(20, 6))
plt.plot(predicted_prots_10[n][1], color='blue')
plt.plot(predicted_prots_10[n][2], color='orange')

# %%
cwd = os.getcwd()
path = cwd + "/" + "models/mouse/fcnn_win_10_epochs_200.pt"
fc_model_win_10.trainNN(num_epochs=50, logging=True, save_path=path, save_after_epochs=50)
predicted_prots_10 = fc_model_win_10.predict_on_test_data()
n = 10
plt.figure(figsize=(20, 6))
plt.plot(predicted_prots_10[n][1], color='blue')
plt.plot(predicted_prots_10[n][2], color='orange')
print(predicted_prots_10[n][0])
# Out:
# tensor(0.1485, grad_fn=<DivBackward0>)

# %%
loss = 0
for protein in predicted_prots_10:
    loss += protein[0]
    
print(loss/len(predicted_prots_10))
# Out:
# tensor(0.2274, grad_fn=<DivBackward0>)

# %%
train_pred = fc_model_win_10.predict_on_outside_data(train_df_list, max_size=20, logging=True)
# Out:
# Seperating Labels
# 0 Dataframes seperated into labels and features.
# Running Predictions

# %%
loss = 0
for protein in train_pred:
    loss += protein[0]
    
print(loss/len(train_pred))
# Out:
# tensor(0.1511, grad_fn=<DivBackward0>)

# %%
n = 15
plt.figure(figsize=(20, 6))
plt.plot(train_pred[n][1], color='blue')
plt.plot(train_pred[n][2], color='orange')

# %%
# fc_model_win_10 = TrainFCNN(10, 40)
# fc_model_win_10.model.load_state_dict(torch.load('./models/mouse/fcnn_win_10_epochs_200.pt'))
# fc_model_win_10.model.eval()
# Out:
# FCNN(
#   (linear1): Linear(in_features=200, out_features=40, bias=True)
#   (linear2): Linear(in_features=40, out_features=10, bias=True)
# )

# %% [markdown]
# ### Testing Window size 7 - Mouse on Mouse

# %%
fc_model_win_7 = TrainFCNN(7,40)

# %%
fc_model_win_7.loadTestTrainData(train_df_list, test_df_list, max_size=1000, logging=True)
# Out:
# Train data extraction started.
# 0 Dataframes seperated into labels and features.
# 100 Dataframes seperated into labels and features.
# 200 Dataframes seperated into labels and features.
# 300 Dataframes seperated into labels and features.
# 400 Dataframes seperated into labels and features.
# 500 Dataframes seperated into labels and features.
# 600 Dataframes seperated into labels and features.
# 700 Dataframes seperated into labels and features.
# 800 Dataframes seperated into labels and features.
# 900 Dataframes seperated into labels and features.
# 1000 Dataframes seperated into labels and features.
# Test data extraction started.
# 0 Dataframes seperated into labels and features.
# 100 Dataframes seperated into labels and features.
# 200 Dataframes seperated into labels and features.
# 300 Dataframes seperated into labels and features.
# 400 Dataframes seperated into labels and features.
# 500 Dataframes seperated into labels and features.
# Test and Train data extracted.

# %%
# cwd = os.getcwd()
# path = cwd + "/" + "models/mouse/fcnn_win_7_epochs_200.pt"
# fc_model_win_7.trainNN(num_epochs=200, logging=True, save_path=path, save_after_epochs=50)
# predicted_prots_7 = fc_model_win_7.predict_on_test_data()

# %%
n = 10
plt.figure(figsize=(20, 6))
plt.plot(predicted_prots_7[n][1], color='blue')
plt.plot(predicted_prots_7[n][2], color='orange')
print(predicted_prots_7[n][0])
# Out:
# tensor(0.1514, grad_fn=<DivBackward0>)

# %%
loss = 0
for protein in predicted_prots_7:
    loss += protein[0]
    
print(loss/len(predicted_prots_7))
# Out:
# tensor(0.1927, grad_fn=<DivBackward0>)

# %% [markdown]
# ### Testing Window size 13 - Mouse on Mouse

# %%
fc_model_win_13 = TrainFCNN(13,40)
fc_model_win_13.loadTestTrainData(train_df_list, test_df_list, max_size=1000, logging=True)
# Out:
# Train data extraction started.
# 0 Dataframes seperated into labels and features.
# 100 Dataframes seperated into labels and features.
# 200 Dataframes seperated into labels and features.
# 300 Dataframes seperated into labels and features.
# 400 Dataframes seperated into labels and features.
# 500 Dataframes seperated into labels and features.
# 600 Dataframes seperated into labels and features.
# 700 Dataframes seperated into labels and features.
# 800 Dataframes seperated into labels and features.
# 900 Dataframes seperated into labels and features.
# 1000 Dataframes seperated into labels and features.
# Test data extraction started.
# 0 Dataframes seperated into labels and features.
# 100 Dataframes seperated into labels and features.
# 200 Dataframes seperated into labels and features.
# 300 Dataframes seperated into labels and features.
# 400 Dataframes seperated into labels and features.
# 500 Dataframes seperated into labels and features.
# Test and Train data extracted.

# %%
cwd = os.getcwd()
path = cwd + "/" + "models/mouse/fcnn_win_13_epochs_200.pt"
fc_model_win_13.trainNN(num_epochs=200, logging=True, save_path=path, save_after_epochs=50)
predicted_prots_13 = fc_model_win_13.predict_on_test_data()
n = 10
plt.figure(figsize=(20, 6))
plt.plot(predicted_prots_13[n][1], color='blue')
plt.plot(predicted_prots_13[n][2], color='orange')
print(predicted_prots_13[n][0])
# Out:
# Epoch: 1 Current Loss: 9.075377464294434 Avg Loss: 9.187772861013569
# Epoch: 6 Current Loss: 4.188659191131592 Avg Loss: 8.065634005576769
# Epoch: 11 Current Loss: 4.918032169342041 Avg Loss: 7.941141496334834
# Epoch: 16 Current Loss: 6.330503463745117 Avg Loss: 7.884787950665341
# Epoch: 21 Current Loss: 11.320874214172363 Avg Loss: 7.8492592866732025
# Epoch: 26 Current Loss: 1.0956858396530151 Avg Loss: 7.828934408446586
# Epoch: 31 Current Loss: 9.106610298156738 Avg Loss: 7.809685578135201
# Epoch: 36 Current Loss: 12.217362403869629 Avg Loss: 7.796278740036024
# Epoch: 41 Current Loss: 8.841374397277832 Avg Loss: 7.790293582931651
# Epoch: 46 Current Loss: 4.375909805297852 Avg Loss: 7.782173594922713
# Epoch: 51 Current Loss: 10.52923583984375 Avg Loss: 7.777950105792242
# Epoch: 56 Current Loss: 9.827657699584961 Avg Loss: 7.768214338231596
# Epoch: 61 Current Loss: 1.0271923542022705 Avg Loss: 7.761365736296591
# Epoch: 66 Current Loss: 8.937792778015137 Avg Loss: 7.756151959767815
# Epoch: 71 Current Loss: 3.62200927734375 Avg Loss: 7.751840134708836
# Epoch: 76 Current Loss: 2.38651967048645 Avg Loss: 7.745553053605011
# Epoch: 81 Current Loss: 11.89547348022461 Avg Loss: 7.746205395833241
# Epoch: 86 Current Loss: 11.689395904541016 Avg Loss: 7.744540605660268
# Epoch: 91 Current Loss: 9.556334495544434 Avg Loss: 7.739184859761003
# Epoch: 96 Current Loss: 10.581449508666992 Avg Loss: 7.734689643827105
# Epoch: 101 Current Loss: 5.660641670227051 Avg Loss: 7.737350859285781
# Epoch: 106 Current Loss: 5.939461708068848 Avg Loss: 7.72945292422532
# Epoch: 111 Current Loss: 3.696441888809204 Avg Loss: 7.7301613325441
# Epoch: 116 Current Loss: 4.702434062957764 Avg Loss: 7.7316208312459045
# Epoch: 121 Current Loss: 8.182201385498047 Avg Loss: 7.728551509850269
# Epoch: 126 Current Loss: 4.702746391296387 Avg Loss: 7.725504113092328
# Epoch: 131 Current Loss: 6.839119911193848 Avg Loss: 7.720379382618823
# Epoch: 136 Current Loss: 8.061832427978516 Avg Loss: 7.722542274264405
# Epoch: 141 Current Loss: 10.863988876342773 Avg Loss: 7.7197725735797
# Epoch: 146 Current Loss: 7.729678153991699 Avg Loss: 7.71939750678715
# Epoch: 151 Current Loss: 7.232830047607422 Avg Loss: 7.717260384243025
# Epoch: 156 Current Loss: 9.900436401367188 Avg Loss: 7.7150650986324285
# Epoch: 161 Current Loss: 4.339895248413086 Avg Loss: 7.716016882029453
# Epoch: 166 Current Loss: 7.75883674621582 Avg Loss: 7.713018205681374
# Epoch: 171 Current Loss: 6.004286289215088 Avg Loss: 7.712929619827247
# Epoch: 176 Current Loss: 12.174419403076172 Avg Loss: 7.708277036240973
# Epoch: 181 Current Loss: 7.612962245941162 Avg Loss: 7.7089629256757055
# Epoch: 186 Current Loss: 10.80019474029541 Avg Loss: 7.708840883026472
# Epoch: 191 Current Loss: 10.567218780517578 Avg Loss: 7.703518549108804
# Epoch: 196 Current Loss: 0.6341400742530823 Avg Loss: 7.703441694174676
# tensor(0.1695, grad_fn=<DivBackward0>)

# %%
loss = 0
for protein in predicted_prots_13:
    loss += protein[0]
    
print(loss/len(predicted_prots_13))
# Out:
# tensor(0.2594, grad_fn=<DivBackward0>)

# %% [markdown]
# ## Testing on Humans Test Set

# %%
test_df_humans_list = extract.load_all_csv('./data/humans/test')

# %%
test_humans_pred = fc_model_win_10.predict_on_outside_data(test_df_humans_list, max_size=500, logging=True)
# Out:
# Seperating Labels
# 0 Dataframes seperated into labels and features.
# 100 Dataframes seperated into labels and features.
# 200 Dataframes seperated into labels and features.
# 300 Dataframes seperated into labels and features.
# 400 Dataframes seperated into labels and features.
# 500 Dataframes seperated into labels and features.
# Running Predictions

# %%
loss = 0
for protein in test_humans_pred:
    loss += protein[0]
    
print(loss/len(test_humans_pred))
# Out:
# tensor(0.2416, grad_fn=<DivBackward0>)

# %%
n = 5
plt.figure(figsize=(20, 6))
plt.plot(test_humans_pred[n][1], color='blue')
plt.plot(test_humans_pred[n][2], color='orange')
